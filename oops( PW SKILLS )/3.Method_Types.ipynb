# %%
# 1. Instance Methods
# Definition: These methods operate on an instance (object) of the class.

# Syntax: The first parameter is always self, which refers to the instance.

# Use: Used to access or modify the object’s attributes.


class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def findAge(self):
        return self.age

per = Person("Vishwa", 99)
print(per.findAge())
# Out:
# 99

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def greet(self):
        print(f"Hello, my name is {self.name}")  # Accesses instance variable

p1 = Person("Alice")
p1.greet()  # Output: Hello, my name is Alice
# Out:
# Hello, my name is Alice

# %%
# 2. Class Methods
# Definition: These methods work with the class itself, not instances.

# Syntax: Use the @classmethod decorator, and the first parameter is cls, referring to the class.

# Use: Used for factory methods or to access/modify class-level attributes.

class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def total_people(cls):
        print(f"Total people: {cls.count}")

p1 = Person()
p2 = Person()
Person.total_people()  # Output: Total people: 2
# Out:
# Total people: 2

# %%
#class method
class Person :

  country = "India"

  @classmethod
  def greet(cls):
    print("Hello from the ", cls.country)

  def __init__(self, name, age):
    self.name = name
    self.age = age

  def findAge(self):
    return self.age


per = Person("Vishwa", 99)
print(per.findAge())

Person.greet()
per.greet()
# Out:
# 99
# Hello from the  India
# Hello from the  India

# %%
# 3. Static Methods
# Definition: These methods don’t access instance or class variables.

# Syntax: Use the @staticmethod decorator. No self or cls parameter.

# Use: Utility functions related to the class.


class Math:
    @staticmethod
    def add(x, y):
        return x + y

print(Math.add(5, 3))  # Output: 8
# Out:
# 8

# %% [markdown]
# ![image.png](attachment:image.png)
